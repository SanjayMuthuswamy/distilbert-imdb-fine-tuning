# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayMuthuswamy/distilbert-imdb-fine-tuning/blob/main/Fine_Tuning_DistilBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers datasets evaluate accelerate torch scikit-learn huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.7 MB/s eta 0:00:00

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# Out:
#   File "/tmp/ipykernel_791/3827820173.py", line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
